# %%
#internship day-2 work problems
current_salary=float(input("enter ur current salary:"))
age=int(input("enter ut age"))
average_experience = (5 + 3 + 7) / 3    # Calculate average: 5.0 years
salary_increase = current_salary * 1.1  # 10% raise
years_until_retirement = 65 - age
print(years_until_retirement)
print(average_experience)
print(salary_increase)       # Years left
skill=input("enter ur skill:")
years_experience=int(input("enter ur experience:"))
if years_experience >= 5:           # "Is experience 5 or more?"
    print("Qualifies for Senior role")

if skill == "Python":               # "Is skill exactly 'Python'?"
    print("Has required skill")
has_degree=bool(input("do u have degree reply it through true or false:"))
has_python_skill=bool(input("do u have python skill reply it through true or false:"))
has_java_skill=bool(input("do u have java skill reply it through true or false:"))

if (has_degree == True) and (years_experience >= 3):
    # BOTH must be true
    print("Qualifies for Mid-level position")

if (has_python_skill == True) or (has_java_skill == True):
    # EITHER can be true
    print("Has programming experience")

# %%
##internship day-2 work problems
result_1= 2 + 3 * 4  
print(result_1)    # Is it 20 or 14?
# Python calculates: 3 * 4 = 12, then + 2 = 14
# Because: Multiplication (*) before Addition (+)
num1 = float(input("Enter first number: "))    # Gets number 1
operator = input("Enter operator: ")          # Gets +, -, *, /
num2 = float(input("Enter second number: "))  # Gets number 2

# The "if-elif" chain checks WHICH operator:
if operator == "+":
    result = num1 + num2      # Addition operator
elif operator == "-":
    result = num1 - num2    
elif operator == "*":
    result=num1 * num2
elif operator == "/":  
    result=num1 / num2     
print(result)      # Subtraction operator
# ... etc
# Out:
# 14
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 6
#       3 print(result_1)    # Is it 20 or 14?
#       4 # Python calculates: 3 * 4 = 12, then + 2 = 14
#       5 # Because: Multiplication (*) before Addition (+)
# ----> 6 num1 = float(input("Enter first number: "))    # Gets number 1
#       7 operator = input("Enter operator: ")          # Gets +, -, *, /
#       8 num2 = float(input("Enter second number: "))  # Gets number 2
#
# ValueError: could not convert string to float: ''

# %%
#internhsip day-3 wokr problems
# --- IGNORE ---    
name=""
skills=["Java","Python","C++"]
print(len(skills)>0)
experince=2
has_degree=True
print(has_degree and experince>=2 and len(skills)>0)
#grade classifeier codes
score = float(input("Enter test score: "))

# This creates a DECISION PATH:
if score >= 90:          # PATH 1: Excellent scores
    grade = "A"
    message = "Excellent!"
elif score >= 80:        # PATH 2: Good scores
    grade = "B"
    message = "Good job!"
elif score >= 70:        # PATH 3: Average scores
    grade = "C"
    message = "Satisfactory"
else:                    # PATH 4: Everything else
    grade = "F"
    message = "Needs help"
print("Grade:",grade)
print(message)
#candidate resume analyiser
candidate=input("enter the candiate name or return no canddiate:")
skills1=["Java","C++","HTML"]
def check_candidate(candidate):
    if not candidate:
        return "No candidate"
    
    if not candidate.skills1:
        return "No skills"
    
    if "Python" not in candidate.skills:
        return "Missing Python"
    
    return "Qualified"
# Out:
# True
# True
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 10
#       8 print(has_degree and experince>=2 and len(skills)>0)
#       9 #grade classifeier codes
# ---> 10 score = float(input("Enter test score: "))
#      12 # This creates a DECISION PATH:
#      13 if score >= 90:          # PATH 1: Excellent scores
#
# ValueError: could not convert string to float: ''
