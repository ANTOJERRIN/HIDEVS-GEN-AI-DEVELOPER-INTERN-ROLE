# %% [markdown]
# **Detailed Explanation**
#
# Understanding the process_feedback Function
# The provided Python function, process_feedback, is a straightforward utility designed to encapsulate and return customer feedback data. It takes a text string and an integer rating, then packages them into a dictionary.
#
# **Core Definition:**
# The process_feedback function is a data processing utility that accepts customer feedback text and a corresponding star rating, then returns this information as a structured dictionary.
#
# **Key Components:**
# Function Signature (def process_feedback(text: str, rating: int) -> dict:):
# def process_feedback: Defines a function named process_feedback.
# text: str: Specifies that the text argument is expected to be a string. This is a type hint, improving code readability and maintainability.
# rating: int: Specifies that the rating argument is expected to be an integer. This is also a type hint.
# -> dict: Indicates that the function is expected to return a dictionary. This is another type hint.
#
# **Docstring ("""Process customer feedback..."""):**
# Provides a concise summary of the function's purpose, its arguments (Args), and what it returns (Returns). This is crucial for documentation and understanding how to use the function.
# Function Body (return {"text": text, "rating": rating}):
# This is the core logic. It creates a new dictionary where:
# The key "text" holds the value of the text argument.
# The key "rating" holds the value of the rating argument.
# The return statement sends this newly created dictionary back as the function's output.
#
# **How It Works:**
# When process_feedback is called, it simply takes the text and rating values passed to it and constructs a dictionary. This dictionary uses predefined keys ("text" and "rating") to store the input values. The function then immediately returns this dictionary. It performs no complex operations like validation, storage, or analysis within itself.
#
# **Practical Applications:**
# This basic function serves as a foundational building block in larger systems:
# Data Standardization: Ensures that feedback data is consistently structured before being passed to other parts of an application (e.g., a database, an analytics module, or an AI model).
# API Endpoints: Could be used as an internal helper function for a web API endpoint that receives feedback from users. The API would call this function to format the incoming data.
# Logging and Storage: The returned dictionary can be easily serialized (e.g., to JSON) and stored in a database or a log file.
# Input for AI Models: The structured dictionary could be the direct input for a sentiment analysis model or a topic modeling algorithm, where the text and rating are features.
#
# **Why It Matters:**
# While simple, this function demonstrates several important programming principles:
# Modularity: It isolates a specific piece of logic (formatting feedback) into a reusable unit.
# Clarity and Readability: Type hints and a clear docstring make the function's purpose and expected inputs/outputs immediately understandable.
# Data Structuring: It provides a consistent way to represent feedback data, which is essential for reliable data processing in any application.
# the above statements is the below code explanation

# %%
def process_feedback(text: str, rating: int) -> dict:
    """
    Process customer feedback.

    Args:
        text: The feedback text
        rating: 1-5 star rating

    Returns:
        Dictionary with processed data
    """
    return {"text": text, "rating": rating}

# %% [markdown]
# leetprompt challenge: feedback system
# You are a zero-shot product review sentiment analysis engine.
#
# TASK:
# Analyze the provided product review and:
# 1. Classify overall sentiment as Positive, Negative, or Neutral.
# 2. Extract specific positive and negative aspects mentioned.
# 3. Provide a short summary.
# 4. Assign a confidence score to the classification.
#
# SENTIMENT DEFINITIONS:
#
# - Positive:
#   The reviewer expresses overall satisfaction, approval, or recommendation.
#   Majority of statements are favorable.
#   Minor criticisms may exist but overall tone is clearly positive.
#
# - Negative:
#   The reviewer expresses dissatisfaction, disappointment, or discouragement.
#   Majority of statements are critical or unfavorable.
#   Minor positive comments may exist but overall tone is negative.
#
# - Neutral:
#   The review is mixed, balanced, purely factual, or lacks strong emotional tone.
#   Positive and negative elements are balanced OR no clear opinion is given.
#
# ASPECT EXTRACTION RULES:
# - Extract only explicitly mentioned product features or qualities.
# - Aspects must be concrete (e.g., "battery life", "customer service", "build quality").
# - Do NOT invent or infer aspects not mentioned.
# - If no aspects are mentioned, return empty arrays.
#
# CONFIDENCE SCORING (0.0 – 1.0):
#
# - 1.0 → Clear, unambiguous sentiment with strong language.
# - 0.8 → Clear overall tone with minor mixed signals.
# - 0.6 → Some ambiguity but dominant tone identifiable.
# - 0.4 → Highly mixed or unclear sentiment.
# - 0.2 → Very unclear or minimal information.
#
# OUTPUT FORMAT (STRICT JSON):
#
# {
#   "sentiment": "Positive/Negative/Neutral",
#   "confidence_score": 0.0-1.0,
#   "positive_aspects": ["array of positive aspects or empty"],
#   "negative_aspects": ["array of negative aspects or empty"],
#   "summary": "brief 1-2 sentence objective summary of the review"
# }
#
# INSTRUCTIONS:
# - Determine overall sentiment only once.
# - Do not output multiple sentiments.
# - Extract aspects separately into positive_aspects and negative_aspects.
# - If sentiment is Neutral, both positive_aspects and negative_aspects may contain items.
# - Return ONLY valid JSON.
# - Do not include explanations, markdown, or additional commentary.
#
# REVIEW:
# {review_text}
