# %%
#internship day-4 work problems
"""age=int(input(""))
has_degree=bool(input(""))
years_exp=int(input(""))
if age >= 18:                    # First: Check basic eligibility
    if has_degree:               # Second: Check education
        if years_exp >= 2:       # Third: Check experience
            print("Fully Qualified")
        else:
            print("Needs more experience")
    else:
        print("Degree required")
else:
    print("Too young")
print("fully qualified")  if (age>=18 and has_degree and years_exp>=2) else print("needs more experience")  
if years_exp >= 5:
    level = "Senior"
else:
    level = "Junior"
level= "Senior" if years_exp>=5 else "Junior"    
print(level)"""
#job qualification checker
age = int(input("Enter age: "))
years_exp = int(input("Years of experience: "))
has_degree = input("Degree? (yes/no): ").lower()#tryingto parse in lowercase characters

# This creates a HIERARCHY of checks:
if age < 18:                          # LEVEL 1: Basic age check
    result = "Too young"
elif years_exp < 2:                   # LEVEL 2: Experience check
    result = "Needs more experience"
elif has_degree == "no":              # LEVEL 3: Education check
    result = "Degree required"
else:                                 # LEVEL 4: Qualification level
    if years_exp >= 5 and has_degree == "yes":
        result = "Senior Level"       # SUB-LEVEL: Senior
    elif years_exp >= 3:
        result = "Mid Level"          # SUB-LEVEL: Mid
    else:
        result = "Junior Level"       # SUB-LEVEL: Junior
print(result)
# Out:
# Mid Level

# %%
candidate={'is_proper_age':25,
           'education':True,
           'experience':3,
           'skills':['Python','Java']}
def is_eligible(candidate):
    return (is_proper_age(candidate['age']) and
            has_education_or_experience(candidate) and
            has_sufficient_skills(candidate.skills))

if is_eligible(candidate):
    hire_candidate()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 10
#       5 def is_eligible(candidate):
#       6     return (is_proper_age(candidate['age']) and
#       7             has_education_or_experience(candidate) and
#       8             has_sufficient_skills(candidate.skills))
# ---> 10 if is_eligible(candidate):
#      11     hire_candidate()
#
# Cell In[1], line 6, in is_eligible(candidate)
#       5 def is_eligible(candidate):
# ----> 6     return (is_proper_age(candidate['age']) and
#       7             has_education_or_experience(candidate) and
#       8             has_sufficient_skills(candidate.skills))
#
# NameError: name 'is_proper_age' is not defined

# %%
name=input("enter ur name")
sheets=int(input("enter no of sheets"))
print(f"hello {name}, you have {sheets} sheets")
# Out:
# hello jerrin, you have 190 sheets
