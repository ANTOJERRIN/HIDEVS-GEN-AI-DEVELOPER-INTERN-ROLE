# %%
#intenrship day-5-for loop structure 
candidates = ["Alice", "Bob", "Charlie", "Diana"]

for candidate in candidates:          # For EACH candidate
    print(f"Processing: {candidate}") # Do this action
    # Send email, score resume, etc.
# Out:
# Processing: Alice
# Processing: Bob
# Processing: Charlie
# Processing: Diana

# %%
qualified_candidates = []
candidates_to_interview = ["Alice", "Bob", "Charlie", "Diana", "Eve"]
index = 0

while len(qualified_candidates) < 3 and index < len(candidates_to_interview):
    candidate = candidates_to_interview[index]
    if is_qualified(candidate):          # Check if qualified
        qualified_candidates.append(candidate)
    index += 1                           # Move to next candidate
    
print(f"Found {len(qualified_candidates)} qualified candidates")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 7
#       5 while len(qualified_candidates) < 3 and index < len(candidates_to_interview):
#       6     candidate = candidates_to_interview[index]
# ----> 7     if is_qualified(candidate):          # Check if qualified
#       8         qualified_candidates.append(candidate)
#       9     index += 1                           # Move to next candidate
#
# NameError: name 'is_qualified' is not defined

# %%
skills = ["Python", "Java", "Python", "SQL", "Java", "Python", "JavaScript"]

# Step 1: Create empty counter dictionary
skill_count = {}

# Step 2: Loop through EACH skill in the list
for skill in skills:
    # Step 3: Check if skill already in dictionary
    if skill in skill_count:
        skill_count[skill] += 1      # Increment count
    else:
        skill_count[skill] = 1       # First time seeing this skill
print("skill_count","=",skill_count)
# Out:
# skill_count = {'Python': 3, 'Java': 2, 'SQL': 1, 'JavaScript': 1}

# %%
index = 0
for candidate in candidates:
    print(f"{index + 1}. {candidate['name']}")
    index += 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 3
#       1 index = 0
#       2 for candidate in candidates:
# ----> 3     print(f"{index + 1}. {candidate['name']}")
#       4     index += 1
#
# TypeError: string indices must be integers, not 'str'

# %%
for index, candidate in enumerate(candidates, start=1):
    print(f"{index}. {candidate['name']}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 for index, candidate in enumerate(candidates, start=1):
# ----> 2     print(f"{index}. {candidate['name']}")
#
# TypeError: string indices must be integers, not 'str'
